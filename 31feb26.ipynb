# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/ATM-Simulation/blob/coding---practice/31feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 14. Develop a Python program to perform list operations on the given values.

# %%
lst = list(map(int, input("Enter list values: ").split()))

print("Original list:", lst)

lst.append(10)
print("After append:", lst)

lst.remove(lst[0])
print("After remove:", lst)

lst.sort()
print("Sorted list:", lst)

lst.reverse()
print("Reversed list:", lst)
# Out:
# Enter list values: 23
# Original list: [23]
# After append: [23, 10]
# After remove: [10]
# Sorted list: [10]
# Reversed list: [10]
